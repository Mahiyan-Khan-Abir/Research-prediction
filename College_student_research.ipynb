# %% [markdown]
# <a href="https://colab.research.google.com/github/Mahiyan-Khan-Abir/Research-prediction/blob/main/College_student_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Admission in the University/adm_data.csv")
print(df)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df1 = pd.DataFrame(df)
df1.isnull()
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating    SOP   LOR   \
# 0         False      False        False              False  False  False
# 1         False      False        False              False  False  False
# 2         False      False        False              False  False  False
# 3         False      False        False              False  False  False
# 4         False      False        False              False  False  False
# ..          ...        ...          ...                ...    ...    ...
# 395       False      False        False              False  False  False
# 396       False      False        False              False  False  False
# 397       False      False        False              False  False  False
# 398       False      False        False              False  False  False
# 399       False      False        False              False  False  False
#
#       CGPA  Research  Chance of Admit
# 0    False     False             False
# 1    False     False             False
# 2    False     False             False
# 3    False     False             False
# 4    False     False             False
# ..     ...       ...               ...
# 395  False     False             False
# 396  False     False             False
# 397  False     False             False
# 398  False     False             False
# 399  False     False             False
#
# [400 rows x 9 columns]

# %%
#Correlation
import matplotlib.pyplot as plt
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style type="text/css">
# #T_6f780_row0_col0, #T_6f780_row1_col1, #T_6f780_row2_col2, #T_6f780_row3_col3, #T_6f780_row4_col4, #T_6f780_row5_col5, #T_6f780_row6_col6, #T_6f780_row7_col7, #T_6f780_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col1, #T_6f780_row1_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col2, #T_6f780_row2_col0 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col3, #T_6f780_row0_col4, #T_6f780_row3_col0, #T_6f780_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col5, #T_6f780_row5_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col6, #T_6f780_row6_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col7, #T_6f780_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_6f780_row0_col8, #T_6f780_row8_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_6f780_row1_col2, #T_6f780_row2_col1 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_6f780_row1_col3, #T_6f780_row3_col1, #T_6f780_row5_col6, #T_6f780_row5_col8, #T_6f780_row6_col5, #T_6f780_row8_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_6f780_row1_col4, #T_6f780_row4_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_6f780_row1_col5, #T_6f780_row5_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_6f780_row1_col6, #T_6f780_row6_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_6f780_row1_col7, #T_6f780_row7_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_6f780_row1_col8, #T_6f780_row8_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_6f780_row2_col3, #T_6f780_row3_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_6f780_row2_col4, #T_6f780_row3_col5, #T_6f780_row4_col2, #T_6f780_row5_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_6f780_row2_col5, #T_6f780_row5_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_6f780_row2_col6, #T_6f780_row6_col2 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_6f780_row2_col7, #T_6f780_row7_col2 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_6f780_row2_col8, #T_6f780_row8_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_6f780_row3_col4, #T_6f780_row4_col3 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_6f780_row3_col6, #T_6f780_row6_col3 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_6f780_row3_col7, #T_6f780_row7_col3 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_6f780_row3_col8, #T_6f780_row8_col3 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_6f780_row4_col5, #T_6f780_row5_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_6f780_row4_col6, #T_6f780_row6_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_6f780_row4_col7, #T_6f780_row7_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_6f780_row4_col8, #T_6f780_row8_col4 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_6f780_row5_col7, #T_6f780_row7_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_6f780_row6_col7, #T_6f780_row7_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_6f780_row6_col8, #T_6f780_row8_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_6f780_row7_col8, #T_6f780_row8_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# </style>
# <table id="T_6f780_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Serial No.</th>
#       <th class="col_heading level0 col1" >GRE Score</th>
#       <th class="col_heading level0 col2" >TOEFL Score</th>
#       <th class="col_heading level0 col3" >University Rating</th>
#       <th class="col_heading level0 col4" >SOP</th>
#       <th class="col_heading level0 col5" >LOR </th>
#       <th class="col_heading level0 col6" >CGPA</th>
#       <th class="col_heading level0 col7" >Research</th>
#       <th class="col_heading level0 col8" >Chance of Admit </th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f780_level0_row0" class="row_heading level0 row0" >Serial No.</th>
#       <td id="T_6f780_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6f780_row0_col1" class="data row0 col1" >-0.097526</td>
#       <td id="T_6f780_row0_col2" class="data row0 col2" >-0.147932</td>
#       <td id="T_6f780_row0_col3" class="data row0 col3" >-0.169948</td>
#       <td id="T_6f780_row0_col4" class="data row0 col4" >-0.166932</td>
#       <td id="T_6f780_row0_col5" class="data row0 col5" >-0.088221</td>
#       <td id="T_6f780_row0_col6" class="data row0 col6" >-0.045608</td>
#       <td id="T_6f780_row0_col7" class="data row0 col7" >-0.063138</td>
#       <td id="T_6f780_row0_col8" class="data row0 col8" >0.042336</td>
#     </tr>
#     <tr>
#       <th id="T_6f780_level0_row1" class="row_heading level0 row1" >GRE Score</th>
#       <td id="T_6f780_row1_col0" class="data row1 col0" >-0.097526</td>
#       <td id="T_6f780_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6f780_row1_col2" class="data row1 col2" >0.835977</td>
#       <td id="T_6f780_row1_col3" class="data row1 col3" >0.668976</td>
#       <td id="T_6f780_row1_col4" class="data row1 col4" >0.612831</td>
#       <td id="T_6f780_row1_col5" class="data row1 col5" >0.557555</td>
#       <td id="T_6f780_row1_col6" class="data row1 col6" >0.833060</td>
#       <td id="T_6f780_row1_col7" class="data row1 col7" >0.580391</td>
#       <td id="T_6f780_row1_col8" class="data row1 col8" >0.802610</td>
#     </tr>
#     <tr>
#       <th id="T_6f780_level0_row2" class="row_heading level0 row2" >TOEFL Score</th>
#       <td id="T_6f780_row2_col0" class="data row2 col0" >-0.147932</td>
#       <td id="T_6f780_row2_col1" class="data row2 col1" >0.835977</td>
#       <td id="T_6f780_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6f780_row2_col3" class="data row2 col3" >0.695590</td>
#       <td id="T_6f780_row2_col4" class="data row2 col4" >0.657981</td>
#       <td id="T_6f780_row2_col5" class="data row2 col5" >0.567721</td>
#       <td id="T_6f780_row2_col6" class="data row2 col6" >0.828417</td>
#       <td id="T_6f780_row2_col7" class="data row2 col7" >0.489858</td>
#       <td id="T_6f780_row2_col8" class="data row2 col8" >0.791594</td>
#     </tr>
#     <tr>
#       <th id="T_6f780_level0_row3" class="row_heading level0 row3" >University Rating</th>
#       <td id="T_6f780_row3_col0" class="data row3 col0" >-0.169948</td>
#       <td id="T_6f780_row3_col1" class="data row3 col1" >0.668976</td>
#       <td id="T_6f780_row3_col2" class="data row3 col2" >0.695590</td>
#       <td id="T_6f780_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_6f780_row3_col4" class="data row3 col4" >0.734523</td>
#       <td id="T_6f780_row3_col5" class="data row3 col5" >0.660123</td>
#       <td id="T_6f780_row3_col6" class="data row3 col6" >0.746479</td>
#       <td id="T_6f780_row3_col7" class="data row3 col7" >0.447783</td>
#       <td id="T_6f780_row3_col8" class="data row3 col8" >0.711250</td>
#     </tr>
#     <tr>
#       <th id="T_6f780_level0_row4" class="row_heading level0 row4" >SOP</th>
#       <td id="T_6f780_row4_col0" class="data row4 col0" >-0.166932</td>
#       <td id="T_6f780_row4_col1" class="data row4 col1" >0.612831</td>
#       <td id="T_6f780_row4_col2" class="data row4 col2" >0.657981</td>
#       <td id="T_6f780_row4_col3" class="data row4 col3" >0.734523</td>
#       <td id="T_6f780_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_6f780_row4_col5" class="data row4 col5" >0.729593</td>
#       <td id="T_6f780_row4_col6" class="data row4 col6" >0.718144</td>
#       <td id="T_6f780_row4_col7" class="data row4 col7" >0.444029</td>
#       <td id="T_6f780_row4_col8" class="data row4 col8" >0.675732</td>
#     </tr>
#     <tr>
#       <th id="T_6f780_level0_row5" class="row_heading level0 row5" >LOR </th>
#       <td id="T_6f780_row5_col0" class="data row5 col0" >-0.088221</td>
#       <td id="T_6f780_row5_col1" class="data row5 col1" >0.557555</td>
#       <td id="T_6f780_row5_col2" class="data row5 col2" >0.567721</td>
#       <td id="T_6f

# %%
x= df.iloc[:, [1,2,6]].values
y= df.iloc[:,7].values
#print(x)
#print(y)

# %% [markdown]
# **Split and Scatter**

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression  
classifier= LogisticRegression(random_state=0)  
classifier.fit(x_train, y_train)  

LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,  
                   intercept_scaling=1, l1_ratio=None, max_iter=100,  
                   multi_class='warn', n_jobs=None, penalty='l2',  
                   random_state=0, solver='warn', tol=0.0001, verbose=0,  
                   warm_start=False)  
y_pred= classifier.predict(x_test)  

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[35 14]
#  [ 9 42]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75        49
#            1       0.75      0.82      0.79        51
#
#     accuracy                           0.77       100
#    macro avg       0.77      0.77      0.77       100
# weighted avg       0.77      0.77      0.77       100
#
# Accuracy: 77.0 %

# %% [markdown]
# **K-Neighbors Classifier (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 8)
classifier.fit(x_train, y_train)

y_pred = classifier.predict(x_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[39 10]
#  [10 41]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80        49
#            1       0.80      0.80      0.80        51
#
#     accuracy                           0.80       100
#    macro avg       0.80      0.80      0.80       100
# weighted avg       0.80      0.80      0.80       100
#
# Accuracy: 80.0 %

# %% [markdown]
# **SVM**

# %%
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import precision_score, recall_score
 

skf = StratifiedKFold(n_splits=10)
clf = svm.SVC(kernel='linear', C=1)

X= df.iloc[:, [5]].values  
Y= df.iloc[:, 6].values 
    
    
from sklearn.svm import SVC # "Support vector classifier"  
classifier = SVC(kernel='linear', random_state=0)  
classifier.fit(x_train, y_train)

#Predicting the test set result  
y_pred= classifier.predict(x_test)  

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
result = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(result)
result1 = classification_report(y_test, y_pred)
print("Classification Report:",)
print (result1)
result2 = accuracy_score(y_test,y_pred)
print("Accuracy:",result2*100,'%')
# Out:
# Confusion Matrix:
# [[37 12]
#  [ 9 42]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78        49
#            1       0.78      0.82      0.80        51
#
#     accuracy                           0.79       100
#    macro avg       0.79      0.79      0.79       100
# weighted avg       0.79      0.79      0.79       100
#
# Accuracy: 79.0 %
